# %% [markdown]
# ## EF5 Output Analysis with Python

# %% [markdown]
# This notebook allows you to plot a hydrograph from a time-series EF5 output file (Comma Separated Values). If observations of streamflow are available in the file, then the hydrogrpah will include error metrics.
#
# Run the following Code cell to download the custom EF5 plotting and analysis functions.

# %%
# Download a copy of ef5_stats.py from the GitHub repository
# !wget https://raw.githubusercontent.com/HyDROSLab/EF5-Analysis/master/ef5_stats.py
# Out:
# --2023-05-19 23:22:06--  https://raw.githubusercontent.com/HyDROSLab/EF5-Analysis/master/ef5_stats.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6995 (6.8K) [text/plain]
# Saving to: ‘ef5_stats.py’
#
# ef5_stats.py        100%[===================>]   6.83K  --.-KB/s    in 0s
#
# 2023-05-19 23:22:06 (60.3 MB/s) - ‘ef5_stats.py’ saved [6995/6995]

# %% [markdown]
# Next, run the following Code cell to import ef5_stats functions.

# %%
# %matplotlib inline
from ef5_stats import make_stats_plot, parse_date

# %% [markdown]
# The python environment is now ready. Next, upload the EF5 time-series output file(s) to the session storage.
#
# **Note:** This is a temporary session, so all files you upload will be deleted once the session is terminated.
#
# Once you have uploaded the file(s). Customize the following Code cell with the correct gauge name. This gauge name is the one you defined in EF5's control file and is part of the output file name. For example, if you defined the gauge name as **mygauge** in the control file and used the CREST model for the simulation, then your output file should be:
#
# ts.**mygauge**.crest.csv

# %%
# Customize the line immediately below with your file's gauge name
EF5_gauge_name = "03206600"

# Make the hydrograph plot using EF5 custom function "make_stats_plot"
make_stats_plot("ts." + EF5_gauge_name + ".crest.csv", EF5_gauge_name)
